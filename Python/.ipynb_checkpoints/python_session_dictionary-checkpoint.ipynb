# %%
d = {'Name':'Nihar','Gender':'male'}
d[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 d = {'Name':'Nihar','Gender':'male'}
# ----> 2 d[0]
#
# KeyError: 0

# %% [markdown]
# 1. dictonary has no indexing
# 2. dictionary is a mutable types
# 3. Keys -> should be immutable, value-> they can be mutable
# 4. Keys Should be unique

# %%
d
# Out:
# {'Name': 'Nihar', 'Gender': 'male'}

# %%
d1 = {[1,2,3]:'Nihar'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 d1 = {[1,2,3]:'Nihar'}
#
# TypeError: unhashable type: 'list'

# %%
d1 = {(1,2,3):'Nihar'}

# %%
d1
# Out:
# {(1, 2, 3): 'Nihar'}

# %%
d1.keys()
# Out:
# dict_keys([(1, 2, 3)])

# %%
d2 = {'name':'nihar','name':'ranjan'}

# %%
d2
# Out:
# {'name': 'ranjan'}

# %%
d3 = {'Name':'Rohit','college':'HCE','Marks':{'M':56,'DS':98}}

# %%
d3
# Out:
# {'Name': 'Rohit', 'college': 'HCE', 'Marks': {'M': 56, 'DS': 98}}

# %%
d
# Out:
# {'Name': 'Nihar', 'Gender': 'male'}

# %%
d['Name']
# Out:
# 'Nihar'

# %%
d['Gender']
# Out:
# 'male'

# %%
d3['Marks']['DS']
# Out:
# 98

# %% [markdown]
# # Edit

# %%
d['Name'] = 'Ranjan'
d
# Out:
# {'Name': 'Ranjan', 'Gender': 'male'}

# %%
d3['Marks']['DS'] = 65
d3
# Out:
# {'Name': 'Rohit', 'college': 'HCE', 'Marks': {'M': 56, 'DS': 65}}

# %%
d.get('Name')
# Out:
# 'Ranjan'

# %%
d3.get('Marks').get('DS')
# Out:
# 65

# %%
d['Age'] = 28

# %%
d
# Out:
# {'Name': 'Ranjan', 'Gender': 'male', 'Age': 28}

# %%
d3['Marks']['M2']=50
d3
# Out:
# {'Name': 'Rohit', 'college': 'HCE', 'Marks': {'M': 56, 'DS': 65, 'M2': 50}}

# %%
d3['Score']['M2']=50
d3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 d3['Score']['M2']=50
#       2 d3
#
# KeyError: 'Score'

# %%
d5 ={} 
del d5

# %%
d4 = {9:1}
d4.clear()
d4
# Out:
# {}

# %%
d1
# Out:
# {(1, 2, 3): 'Nihar'}

# %%
d2
# Out:
# {'name': 'ranjan'}

# %%
d3
# Out:
# {'Name': 'Rohit', 'college': 'HCE', 'Marks': {'M': 56, 'DS': 65, 'M2': 50}}

# %%
for i in d3:
    print(i)
# Out:
# Name
# college
# Marks

# %%
for i in d3:
    print(i,' ',d3[i])
# Out:
# Name   Rohit
# college   HCE
# Marks   {'M': 56, 'DS': 65, 'M2': 50}

# %%
'Rohit' in d3
# Out:
# False

# %%
'Name' in d3
# Out:
# True

# %%
len(d3)
# Out:
# 3

# %%
min(d3)
# Out:
# 'Marks'

# %%
max(d3)
# Out:
# 'college'

# %%
sum(d3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 sum(d3)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
sorted(d3)
# Out:
# ['Marks', 'Name', 'college']

# %%
sorted(d3,reverse=True)
# Out:
# ['college', 'Name', 'Marks']

# %%
d3.keys()
# Out:
# dict_keys(['Name', 'college', 'Marks'])

# %%
d3.values()
# Out:
# dict_values(['Rohit', 'HCE', {'M': 56, 'DS': 65, 'M2': 50}])

# %%
d3.items()
# Out:
# dict_items([('Name', 'Rohit'), ('college', 'HCE'), ('Marks', {'M': 56, 'DS': 65, 'M2': 50})])
